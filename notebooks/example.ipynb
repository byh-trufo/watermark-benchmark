# %% [markdown]
# Example usage.

# %%
"""
SPDX-FileCopyrightText: © 2024 Trufo™ <engineering@trufo.ai>
SPDX-License-Identifier: MIT
"""
# setup
import os
os.chdir(os.getcwd().split('/notebooks')[0])
import nest_asyncio
nest_asyncio.apply()

# imports
import pandas as pd
import bench
bench.simple_logging_setup()
from wrappers.ref_wrapper import DDWrapper, DDSWrapper

# %%
wrappers = [DDWrapper, DDSWrapper]
datasets = [bench.BenchmarkDataset.IMG_1]
evaluations = [bench.BenchmarkEvaluation.IMG_SIMPLE, bench.BenchmarkEvaluation.IMG_ROBUSTNESS]

for wrapper in wrappers:
    for dataset in datasets:
        for evaluation in evaluations:
            bench.benchmark(wrapper, dataset, evaluation)
# Out:
# 2024-02-17 18:50:56,645 - root.INFO [bench.py:85] - The results file REF_DWTDCT.IMG_1.IMG_SIMPLE already exists. If you would like to override the file, please set the override argument to True.
# 2024-02-17 18:50:56,646 - root.INFO [bench.py:85] - The results file REF_DWTDCT.IMG_1.IMG_ROBUSTNESS already exists. If you would like to override the file, please set the override argument to True.
# 2024-02-17 18:50:56,647 - root.INFO [bench.py:85] - The results file REF_DWTDCTSVD.IMG_1.IMG_SIMPLE already exists. If you would like to override the file, please set the override argument to True.
# 2024-02-17 18:50:56,648 - root.INFO [bench.py:85] - The results file REF_DWTDCTSVD.IMG_1.IMG_ROBUSTNESS already exists. If you would like to override the file, please set the override argument to True.

# %%
from analysis.analyze import ImageAnalysis

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 25)
pd.set_option('display.width', 250)

analysis = ImageAnalysis('*REF*IMG_1*')

# %%
analysis.df_score
# Out:
#                                       enc_count  enc_ntime   enc_psnr  enc_sdsm   enc_pcpa  dec_count  dec_ntime  dec_score
# watermark     dataset evaluation
# REF_DWTDCT    IMG_1   IMG_ROBUSTNESS         10   1.889218  40.123676  4.862041  74.796708        601   0.085712  12.811980
#                       IMG_SIMPLE             10   1.972222  40.123676  4.862041  74.796708         20   0.102013  50.000000
# REF_DWTDCTSVD IMG_1   IMG_ROBUSTNESS         10   6.106133  40.181594  5.215460  41.869423        601   0.274712  27.454243
#                       IMG_SIMPLE             10   5.625815  40.181594  5.215460  41.869423         20   0.273491  90.000000

# %%
analysis.df_edit
# Out:
#                                                      error  detected  decoded  count     ntime
# watermark     dataset evaluation     edit_type
# REF_DWTDCT    IMG_1   IMG_ROBUSTNESS                     0         0        0     10  0.188922
#                                      IEAlterA            0        88       35     90  0.093215
#                                      IEBase              0        20       10     20  0.100307
#                                      IEComposeA          0        60        0     60  0.071290
#                                      IECompressJPEG      0       110        4    110  0.087917
#                                      IECrop              0        65        5     80  0.066745
#                                      IEFilterA           0        60       11     60  0.094257
#                                      IEFilterB           0        30       10     30  0.095215
#                                      IERescale           0        71        1     71  0.080151
#                                      IERotateA           0        30        1     30  0.095754
#                                      IERotateB           0        50        0     50  0.095085
#                       IMG_SIMPLE                         0         0        0     10  0.197222
#                                      IEBase              0        20       10     20  0.102013
# REF_DWTDCTSVD IMG_1   IMG_ROBUSTNESS                     0         0        0     10  0.610613
#                                      IEAlterA            0        88       60     90  0.286235
#                                      IEBase              0        20       18     20  0.294363
#                                      IEComposeA          0        60        3     60  0.260500
#                                      IECompressJPEG      0       110       38    110  0.285944
#                                      IECrop              0        65        9     80  0.204239
#                                      IEFilterA           0        60       11     60  0.295666
#                                      IEFilterB           0        30       19     30  0.313724
#                                      IERescale           0        71        2     71  0.259519
#                                      IERotateA           0        30        3     30  0.300367
#                                      IERotateB           0        50        2     50  0.308844
#                       IMG_SIMPLE                         0         0        0     10  0.562581
#                                      IEBase              0        20       18     20  0.273491

# %%
analysis.df_per
# Out:
#         watermark dataset      evaluation   content_id content_dimensions  time_taken_ms  error       psnr      ssim       pcpa  content_size  detected  decoded  total
# 0      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS     anya_heh      [495, 880, 3]             69  False  43.369196  0.973465  73.665276           660        61        1     61
# 1      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS        boats      [576, 787, 3]             79  False  39.574643  0.965354  78.090376           673        61       15     61
# 2      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS     cat_snow    [2000, 3000, 3]           1265  False  42.645889  0.975279  74.800090          2449        60       15     60
# 3      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS      digital      [256, 256, 3]             12  False  32.818396  0.902249  65.952841           256        48        0     57
# 4      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS  eames_chair      [285, 400, 3]             17  False  42.409397  0.984894  74.675001           338        58        0     60
# 5      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS         lena      [512, 512, 3]             51  False  36.762087  0.944245  79.886351           512        59        1     61
# 6      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS      mandril      [512, 512, 3]             49  False  40.338936  0.985043  75.351197           512        59       16     61
# 7      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS  nassau_hall    [3539, 5184, 3]           3699  False  39.286547  0.988490  82.398458          4283        59       15     59
# 8      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS    pope_coat      [561, 442, 3]             46  False  42.351705  0.973760  71.043499           498        58       14     60
# 9      REF_DWTDCT   IMG_1  IMG_ROBUSTNESS       yellow     [980, 2243, 3]            353  False  41.679966  0.963363  74.365604          1483        61        0     61
# 10     REF_DWTDCT   IMG_1      IMG_SIMPLE     anya_heh      [495, 880, 3]             88  False  43.369196  0.973465  73.665276           660         2        0      2
# 11     REF_DWTDCT   IMG_1      IMG_SIMPLE        boats      [576, 787, 3]             74  False  39.574643  0.965354  78.090376           673         2        2      2
# 12     REF_DWTDCT   IMG_1      IMG_SIMPLE     cat_snow    [2000, 3000, 3]           1086  False  42.645889  0.975279  74.800090          2449         2        2      2
# 13     REF_DWTDCT   IMG_1      IMG_SIMPLE      digital      [256, 256, 3]             13  False  32.818396  0.902249  65.952841           256         2        0      2
# 14     REF_DWTDCT   IMG_1      IMG_SIMPLE  eames_chair      [285, 400, 3]             18  False  42.409397  0.984894  74.675001           338         2        0      2
# 15     REF_DWTDCT   IMG_1      IMG_SIMPLE         lena      [512, 512, 3]             51  False  36.762087  0.944245  79.886351           512         2        0      2
# 16     REF_DWTDCT   IMG_1      IMG_SIMPLE      mandril      [512, 512, 3]             49  False  40.338936  0.985043  75.351197           512         2        2      2
# 17     REF_DWTDCT   IMG_1      IMG_SIMPLE  nassau_hall    [3539, 5184, 3]           4004  False  39.286547  0.988490  82.398458          4283         2        2      2
# 18     REF_DWTDCT   IMG_1      IMG_SIMPLE    pope_coat      [561, 442, 3]             51  False  42.351705  0.973760  71.043499           498         2        2      2
# 19     REF_DWTDCT   IMG_1      IMG_SIMPLE       yellow     [980, 2243, 3]            451  False  41.679966  0.963363  74.365604          1483         2        0      2
# 20  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS     anya_heh      [495, 880, 3]            235  False  42.543622  0.985216  35.211809           660        61       18     61
# 21  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS        boats      [576, 787, 3]            264  False  38.850430  0.972195  44.979012           673        61       17     61
# 22  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS     cat_snow    [2000, 3000, 3]           3366  False  41.466263  0.984556  38.051653          2449        60       17     60
# 23  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS      digital      [256, 256, 3]             55  False  32.789726  0.911358  42.351303           256        48       14     57
# 24  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS  eames_chair      [285, 400, 3]             64  False  42.241138  0.989578  45.666918           338        58        0     60
# 25  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS         lena      [512, 512, 3]            178  False  36.516359  0.949485  50.711494           512        59       20     61
# 26  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS      mandril      [512, 512, 3]            148  False  46.881445  0.999082  45.503374           512        59       25     61
# 27  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS  nassau_hall    [3539, 5184, 3]          11351  False  38.368911  0.988182  57.169099          4283        59       20     59
# 28  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS    pope_coat      [561, 442, 3]            206  False  40.912179  0.976850  27.535019           498        58       17     60
# 29  REF_DWTDCTSVD   IMG_1  IMG_ROBUSTNESS       yellow     [980, 2243, 3]           1578  False  41.245869  0.974351  43.791108          1483        61       17     61
# 30  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE     anya_heh      [495, 880, 3]            220  False  42.543622  0.985216  35.211809           660         2        2      2
# 31  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE        boats      [576, 787, 3]            270  False  38.850430  0.972195  44.979012           673         2        2      2
# 32  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE     cat_snow    [2000, 3000, 3]           3319  False  41.466263  0.984556  38.051653          2449         2        2      2
# 33  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE      digital      [256, 256, 3]             39  False  32.789726  0.911358  42.351303           256         2        2      2
# 34  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE  eames_chair      [285, 400, 3]             55  False  42.241138  0.989578  45.666918           338         2        0      2
# 35  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE         lena      [512, 512, 3]            155  False  36.516359  0.949485  50.711494           512         2        2      2
# 36  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE      mandril      [512, 512, 3]            124  False  46.881445  0.999082  45.503374           512         2        2      2
# 37  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE  nassau_hall    [3539, 5184, 3]          11150  False  38.368911  0.988182  57.169099          4283         2        2      2
# 38  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE    pope_coat      [561, 442, 3]            145  False  40.912179  0.976850  27.535019           498         2        2      2
# 39  REF_DWTDCTSVD   IMG_1      IMG_SIMPLE       yellow     [980, 2243, 3]           1195  False  41.245869  0.974351  43.791108          1483         2        2      2
